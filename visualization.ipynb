# %% [markdown]
# #  Visualization

# %% [markdown]
# **Importing dependencies**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Providing data**

# %%
player_data = pd.read_csv("datasets/player_data.csv")
players = pd.read_csv("datasets/Players.csv")
season_stats = pd.read_csv("datasets/Seasons_Stats.csv")

# %% [markdown]
# **Feature engineering**

# %%
# new player_data feature
player_data["weight_kg"] = (
    player_data["weight"].astype(float) * 0.453592
)  # weight in kilograms

# new players feature
players["age"] = pd.to_datetime(players["born"]).apply(
    lambda x: (pd.to_datetime("today").year - x.year)
)  # players age

season_stats["PTS_per_game"] = (
    season_stats["PTS"] / season_stats["G"]
)  # average points per game

# %% [markdown]
# **Data info**

# %%
print(player_data.head())
print(players.head())
print(season_stats.head())
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college   weight_kg
# 0     June 24, 1968                        Duke University  108.862080
# 1     April 7, 1946                  Iowa State University  106.594120
# 2    April 16, 1947  University of California, Los Angeles  102.058200
# 3     March 9, 1969             Louisiana State University   73.481904
# 4  November 3, 1974              San Jose State University  101.151016
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state   age
# 0               Indiana University  1918.0          NaN         NaN  53.0
# 1           University of Kentucky  1921.0     Yorktown     Indiana  53.0
# 2         University of Notre Dame  1924.0          NaN         NaN  53.0
# 3  North Carolina State University  1925.0          NaN         NaN  53.0
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky  53.0
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS  PTS_per_game
# 0  ...  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0      7.269841
# 1  ...  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0      5.693878
# 2  ...  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0      6.537313
# 3  ...  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0      4.200000
# 4  ...  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0      4.538462
#
# [5 rows x 54 columns]

# %% [markdown]
# **Player_data positions visualization**

# %%
sns.countplot(x="position", data=player_data)
plt.title("Player Positions")
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Players height visualization**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(players["height"], bins=20)
plt.title("Player Heights")
plt.xlabel("Height (cm)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Season_stats visualization**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="PTS", y="AST", data=season_stats)
plt.title("Points vs Assists")
plt.xlabel("Points")
plt.ylabel("Assists")
plt.show()
